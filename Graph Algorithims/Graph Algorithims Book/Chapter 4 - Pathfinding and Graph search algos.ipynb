# %% [markdown]
# # Chapter 4 - Pathfinding and Graph Search Algos
#
#
#
#
#
# ## Introduction
#
# * Graph search algos explore a graph either for general discovery or explicit search. These algorithims carve paths through the graph, but there is no expectation that those paths are computationally optimal.
# * Pathfinding algos build on graph search algos and explore routes between nodes.
# * Starting at one node and traversing through relationships until the destination has been reached.
#
#
# ### Algos that are covered
#
#
# Shortest Path, with two useful variations (A* and Yen’s)
# Finding the shortest path or paths between two chosen nodes
#
# All Pairs Shortest Path and Single Source Shortest Path
# For finding the shortest paths between all pairs or from a chosen node to all others
#
# Minimum Spanning Tree
# For finding a connected tree structure with the smallest cost for visiting all nodes from a chosen node
#
# Random Walk
# Because it’s a useful preprocessing/sampling step for machine learning workflows and other graph algorithms
#
# ![image.png](attachment:image.png)
#
#
# ## Overview of Pathfinding and Graph Search algorithims
#
#
#
# | Algo Type                   | What it does                                                                                                  | Example use                                                                         | Spark Example | Neo4j Example |
# |-----------------------------|---------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------|---------------|---------------|
# | Breadth First Search        | Traverses a tree structure by fanning out to explore  the nearest neighbors and then their sublevel neighbors | Locating neighbor nodes in a GPS system to identify nearby places of interest       |  Yes          | No            |
# | Depth First Search          | Traverses a tree structure by exploring as far as possible down each branch before backtracking               | Discovering an optimal solution path in gaming simulations with hierarchial choices | Yes           | Yes           |
# | Shortest Path (A*,Yens)     | Calculate shortest path between nodes                                                                         | Finding driving direction between two locations                                     | Yes           | Yes           |
# | All Pairs Shortest Paths    | Calculates the shortest path between all pairs of nodes in the graph                                          | Evaluate alternate routes around a traffic jam                                      | Yes           | Yes           |
# | Single Source shortest Path | Calculates the shortest path between a single root  node and all other nodes                                  | Least cost routing of phone calls                                                   | Yes           | Yes           |
# | Minimum spanning tree       | Calculates the path in a connected tree structure with the  smallest cost for visiting all nodes              | Optimizing connecting routing such as laying cable                                  | No            | Yes           |
# | Random Malk                 | Returns a list of nodes along a path of specific size by randomly choosing relatonships to traverse           | Augmenting training for machine learning or data for a graph algo                   | No            | Yes           |
